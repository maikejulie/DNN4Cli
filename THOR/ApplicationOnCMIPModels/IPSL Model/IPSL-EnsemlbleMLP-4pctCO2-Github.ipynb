# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import intake,yaml
import intake_esm
from scipy import special
import keras
from keras.models import Model
from keras.layers import Dense, Input

from netCDF4 import Dataset
import scipy as sp
import scipy.io as sp_io
from mpl_toolkits.basemap import Basemap, cm, shiftgrid
import seaborn as sns
from matplotlib.colors import ListedColormap
colours=sns.color_palette('colorblind', 10)
my_cmap = ListedColormap(colours)

# %%
# %pip install git+https://github.com/jbusecke/cmip6_preprocessing.git
# Out:
# Collecting git+https://github.com/jbusecke/cmip6_preprocessing.git
#   Cloning https://github.com/jbusecke/cmip6_preprocessing.git to /tmp/pip-req-build-j75rzmsq
#   Running command git clone -q https://github.com/jbusecke/cmip6_preprocessing.git /tmp/pip-req-build-j75rzmsq
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: pandas in /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages (from cmip6-preprocessing==0.3.2) (1.2.4)
# Requirement already satisfied: xgcm in /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages (from cmip6-preprocessing==0.3.2) (0.5.2)
# Requirement already satisfied: xarray in /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages (from cmip6-preprocessing==0.3.2) (0.18.2)
# Requirement already satisfied: cftime in /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages (from cmip6-preprocessing==0.3.2) (1.5.0)
# Requirement already satisfied: numpy in /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages (from cmip6-preprocessing==0.3.2) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages (from pandas->cmip6-preprocessing==0.3.2) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages (from pandas->cmip6-preprocessing==0.3.2) (2021.1)
# Requirement already satisfied: six>=1.5 in /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas->cmip6-preprocessing==0.3.2) (1.16.0)
# Requirement already satisfied: setuptools>=40.4 in /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages (from xarray->cmip6-preprocessing==0.3.2) (49.6.0.post20210108)
# Requirement already satisfied: future in /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages (from xgcm->cmip6-preprocessing==0.3.2) (0.18.2)
# Requirement already satisfied: dask in /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages (from xgcm->cmip6-preprocessing==0.3.2) (2021.5.0)
# Requirement already satisfied: docrep<=0.2.7 in /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages (from xgcm->cmip6-preprocessing==0.3.2) (0.2.7)
# Requirement already satisfied: cloudpickle>=1.1.1 in /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages (from dask->xgcm->cmip6-preprocessing==0.3.2) (1.6.0)
# Requirement already satisfied: pyyaml in /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages (from dask->xgcm->cmip6-preprocessing==0.3.2) (5.4.1)
# Requirement already satisfied: partd>=0.3.10 in /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages (from dask->xgcm->cmip6-preprocessing==0.3.2) (1.2.0)
# Requirement already satisfied: toolz>=0.8.2 in /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages (from dask->xgcm->cmip6-preprocessing==0.3.2) (0.11.1)
# Requirement already satisfied: fsspec>=0.6.0 in /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages (from dask->xgcm->cmip6-preprocessing==0.3.2) (2021.5.0)
# Requirement already satisfied: locket in /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages (from partd>=0.3.10->dask->xgcm->cmip6-preprocessing==0.3.2) (0.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from cmip6_preprocessing.preprocessing import combined_preprocessing
from cmip6_preprocessing.preprocessing import (correct_units,rename_cmip6)

# %%
def pp_enso(ds):
    ds = ds.copy()   #the wrapper function makes a copy of the ds and works from this
    ds = rename_cmip6(ds)
    #ds = fix_time(ds)
    #ds = fix_units(ds)
    #ds = correct_units(ds)
    return ds

# %% [markdown]
# ## Retrieve for the data (here example of IPSL-4%Co2)
#
# for the other models and scenarios, please change the variable "expname_filter" and "model_filter"

# %%
col_url = "https://cmip6-nc.s3.us-east-2.amazonaws.com/esgf-world.json" 
col = intake.open_esm_datastore(col_url)

# %%
# %pwd
# Out:
# '/home/jovyan/DNN4Cli/THOR/ApplicationOnCMIPModels'

# %%
#define location of weights file and image output here
import sys,os
wgtsdir = "../../ensembleMLP"
imgdir = "png_4pctCO2_IPSL"
if(os.path.exists(wgtsdir)):
    print("weight dir exists")
else:
    sys.exit("weights directory is invalid")
if(os.path.exists(wgtsdir+'/vanillamodel_0.h5')):
    print("weight file exists")
else:
    sys.exit("weights directory is invalid:"+wgtsdir+'/vanillamodel_0.h5')   
    
if not os.path.exists(imgdir):
    os.makedirs(imgdir)
# Out:
# weight dir exists
# weight file exists

# %%
#Examples to just search for what we want from the catalog
expname_filter = ['abrupt-4xCO2']
table_id_filter = 'Omon'
model_filter = 'IPSL-CM6A-LR'
#variable_id_filter = "zos"
grid_label_filter = 'gn'
ens_filter = "r1i1p1f1"
version_filter = "v20190118"
temporal_subset_filter =  "245001-274912"

cat = col.search(experiment_id=expname_filter,
                 mip_table=table_id_filter,
                 model=model_filter,
                 variable=['zos'],
                 grid_label=grid_label_filter,
                 ensemble_member = ens_filter,
                 version = version_filter,
                 
                 
                )

col_tauuo = col.search(experiment_id=expname_filter,
                       model=model_filter,
                       mip_table=table_id_filter,
                       grid_label=grid_label_filter,
                       variable=['tauuo'],
                       ensemble_member = ens_filter,
                       version = version_filter
                       )

col_tauvo = col.search(experiment_id=expname_filter,
                       model=model_filter,
                       mip_table=table_id_filter,
                       grid_label=grid_label_filter,
                       variable=['tauvo'],
                       ensemble_member = ens_filter,
                       version = version_filter
                       )

col_bathm = col.search(experiment_id=['1pctCO2'],
                       model=model_filter,
                       mip_table='Ofx',
                       grid_label=grid_label_filter,
                       variable='deptho'
                       )

# %%
cat
# Out:
# <p><strong>gfdltest catalog with 1 dataset(s) from 3 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>project</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>institute</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>model</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>experiment_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>modeling_realm</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>mip_table</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>ensemble_member</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>grid_label</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>variable</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>temporal subset</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>version</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>path</th>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
cat.df
# Out:
#   project institute         model experiment_id frequency modeling_realm  \
# 0   CMIP6      IPSL  IPSL-CM6A-LR  abrupt-4xCO2       mon          ocean
# 1   CMIP6      IPSL  IPSL-CM6A-LR  abrupt-4xCO2       mon          ocean
# 2   CMIP6      IPSL  IPSL-CM6A-LR  abrupt-4xCO2       mon          ocean
#
#   mip_table ensemble_member grid_label variable temporal subset    version  \
# 0      Omon        r1i1p1f1         gn      zos   185001-214912  v20190118
# 1      Omon        r1i1p1f1         gn      zos   215001-244912  v20190118
# 2      Omon        r1i1p1f1         gn      zos   245001-274912  v20190118
#
#                                                 path
# 0  s3://esgf-world/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/a...
# 1  s3://esgf-world/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/a...
# 2  s3://esgf-world/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/a...

# %%
col_bathm.df
# Out:
#   project institute         model experiment_id frequency modeling_realm  \
# 0   CMIP6      IPSL  IPSL-CM6A-LR       1pctCO2       NaN            NaN
#
#   mip_table ensemble_member grid_label variable temporal subset    version  \
# 0       Ofx        r1i1p1f1         gn   deptho             NaN  v20180727
#
#                                                 path
# 0  s3://esgf-world/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/1...

# %%
col_tauuo.df
# Out:
#   project institute         model experiment_id frequency modeling_realm  \
# 0   CMIP6      IPSL  IPSL-CM6A-LR  abrupt-4xCO2       mon          ocean
# 1   CMIP6      IPSL  IPSL-CM6A-LR  abrupt-4xCO2       mon          ocean
# 2   CMIP6      IPSL  IPSL-CM6A-LR  abrupt-4xCO2       mon          ocean
#
#   mip_table ensemble_member grid_label variable temporal subset    version  \
# 0      Omon        r1i1p1f1         gn    tauuo   185001-214912  v20190118
# 1      Omon        r1i1p1f1         gn    tauuo   215001-244912  v20190118
# 2      Omon        r1i1p1f1         gn    tauuo   245001-274912  v20190118
#
#                                                 path
# 0  s3://esgf-world/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/a...
# 1  s3://esgf-world/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/a...
# 2  s3://esgf-world/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/a...

# %%
col_tauvo.df
# Out:
#   project institute         model experiment_id frequency modeling_realm  \
# 0   CMIP6      IPSL  IPSL-CM6A-LR  abrupt-4xCO2       mon          ocean
# 1   CMIP6      IPSL  IPSL-CM6A-LR  abrupt-4xCO2       mon          ocean
# 2   CMIP6      IPSL  IPSL-CM6A-LR  abrupt-4xCO2       mon          ocean
#
#   mip_table ensemble_member grid_label variable temporal subset    version  \
# 0      Omon        r1i1p1f1         gn    tauvo   185001-214912  v20190118
# 1      Omon        r1i1p1f1         gn    tauvo   215001-244912  v20190118
# 2      Omon        r1i1p1f1         gn    tauvo   245001-274912  v20190118
#
#                                                 path
# 0  s3://esgf-world/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/a...
# 1  s3://esgf-world/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/a...
# 2  s3://esgf-world/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/a...

# %% [markdown]
# ### Read data

# %%
#dset_dict_zos = cat.to_dataset_dict(cdf_kwargs={'chunks': {'time': 20}}, storage_options={'anon':True})
dset_dict_zos = cat.to_dataset_dict(cdf_kwargs={'decode_times': True,'use_cftime': True,'chunks': {'time': 20}},preprocess = pp_enso, storage_options={'anon':True})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'project.institute.model.experiment_id.mip_table'
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:00<00:00]
#     </div>

# %%
dset_dict_tauuo = col_tauuo.to_dataset_dict(cdf_kwargs={'decode_times': True,'use_cftime': True,'chunks': {'time': 20}}, preprocess = pp_enso,storage_options={'anon':True})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'project.institute.model.experiment_id.mip_table'
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:00<00:00]
#     </div>

# %%
dset_dict_tauvo = col_tauvo.to_dataset_dict(cdf_kwargs={'decode_times': True,'use_cftime': True,'chunks': {'time': 20}}, preprocess = pp_enso, storage_options={'anon':True})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'project.institute.model.experiment_id.mip_table'
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:00<00:00]
#     </div>

# %%
dset_dict_bathm = col_bathm.to_dataset_dict(storage_options={'anon':True},preprocess = pp_enso)
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'project.institute.model.experiment_id.mip_table'
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:00<00:00]
#     </div>

# %%
#these dictionaries have only key value that's why they are all identical
zos_xr = dset_dict_zos['CMIP6.IPSL.IPSL-CM6A-LR.abrupt-4xCO2.Omon'] 
tauuo_xr = dset_dict_tauuo['CMIP6.IPSL.IPSL-CM6A-LR.abrupt-4xCO2.Omon']
tauvo_xr = dset_dict_tauvo['CMIP6.IPSL.IPSL-CM6A-LR.abrupt-4xCO2.Omon']
#This is the diiferent one among them
bathm_xr = dset_dict_bathm["CMIP6.IPSL.IPSL-CM6A-LR.1pctCO2.Ofx"]

# %%
bathm_xr
# Out:
# <xarray.Dataset>
# Dimensions:          (bnds: 2, ensemble_member: 1, lev: 75, vertex: 4, x: 362, y: 332)
# Coordinates:
#     lat              (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     lon              (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#   * lev              (lev) float32 0.5058 1.556 2.668 ... 5.698e+03 5.902e+03
#   * ensemble_member  (ensemble_member) <U8 'r1i1p1f1'
# Dimensions without coordinates: bnds, vertex, x, y
# Data variables:
#     lon_bounds       (y, x, vertex) float32 dask.array<chunksize=(332, 362, 4), meta=np.ndarray>
#     lat_bounds       (y, x, vertex) float32 dask.array<chunksize=(332, 362, 4), meta=np.ndarray>
#     area             (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     lev_bounds       (lev, bnds) float32 dask.array<chunksize=(75, 2), meta=np.ndarray>
#     deptho           (ensemble_member, lev, y, x) float32 dask.array<chunksize=(1, 75, 332, 362), meta=np.ndarray>
# Attributes: (12/52)
#     name:                    /ccc/work/cont003/gencmip6/p86maf/IGCM_OUT/IPSLC...
#     Conventions:             CF-1.7 CMIP-6.2
#     creation_date:           2018-05-02T16:58:21Z
#     description:             DECK: 1pctCO2
#     title:                   IPSL-CM6A-LR model output prepared for CMIP6 / C...
#     activity_id:             CMIP
#     ...                      ...
#     dr2xml_md5sum:           00e1a4f623b35a33620b9828c66bd1c8
#     model_version:           6.1.2
#     tracking_id:             hdl:21.14100/f78f16ec-ed65-4450-b90b-22554ee5dc4f
#     history:                 Thu Jul 26 18:44:14 2018: ncatted -O -a tracking...
#     intake_esm_varname:      ['deptho']
#     intake_esm_dataset_key:  CMIP6.IPSL.IPSL-CM6A-LR.1pctCO2.Ofx

# %%
lon = bathm_xr.lon
lon
# Out:
# <xarray.DataArray 'lon' (y: 332, x: 362)>
# dask.array<open_dataset-f691880c48b1a2bc3d279a9e6cfb66f0nav_lon, shape=(332, 362), dtype=float32, chunksize=(332, 362), chunktype=numpy.ndarray>
# Coordinates:
#     lat      (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     lon      (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
# Dimensions without coordinates: y, x
# Attributes:
#     standard_name:  longitude
#     long_name:      Longitude
#     units:          degrees_east
#     bounds:         bounds_nav_lon

# %%
lat = bathm_xr.lat
lat.shape
# Out:
# (332, 362)

# %%
plt.imshow(np.sum(depth[0], 0))
plt.colorbar()

# %%
np.savez("bathm_lat_lon.npz", x =lat ,y= lon, z = depth)

# %% [markdown]
# ### Some plotting

# %%
plt.figure(figsize=(15,15))

plt.subplot(2,2,1)
zos_xr.zos.sel(time=slice("1992", "2011")).mean(axis=1).plot()

plt.subplot(2,2,2)
bathm_xr.deptho[0,:,:,:].max(axis=0).plot()

plt.subplot(2,2,3)
tauuo_xr.tauuo.sel(time=slice("1992", "2011")).mean(axis=1).plot()

plt.subplot(2,2,4)
tauvo_xr.tauvo.sel(time=slice("1992", "2011")).mean(axis=1).plot()
# Out:
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)

# %% [markdown]
# ### Preparing the features for the EnsembleMLP

# %%
def grad(d,y,x):
    "Returns a three point derivative."
    g0, g1 = np.gradient(d)
    grady=g0/y
    gradx=g1/x
    return grady, gradx

# %%
Bathm = bathm_xr.deptho[0,:,:,:].max(axis=0)  ###This is specific to IPSL bathymetry
####
lonRoll = np.roll(Bathm.lon.values, axis=1, shift=-1)
Londiff = lonRoll - Bathm.lon.values
latDiff=1.111774765625000e+05
latY=np.gradient(Bathm.lat.values, axis=0)*latDiff
lonX=np.abs(np.cos(Bathm.lat.values*np.pi/180))*latDiff*Londiff
####
Omega=7.2921e-5
f=(2*Omega*np.sin(Bathm.lat.values*np.pi/180))

# %%
from pickle import load
#######!!!!!! it might ask you to use scikit-learn 0.22.2.post1 !!!!!! check if you get the good .mean_ and .scale_
#(array([-2.20681035e-11,  7.85894841e-03,  1.92149912e-08,  1.38805767e-07,
#         3.96657293e+03, -1.45941754e-04,  5.42086609e-04, -1.21754470e-05]),
# array([1.46399667e-10, 7.07289355e-01, 1.89893314e-07, 4.55081599e-07,
#        1.44475515e+03, 4.87804804e-03, 4.64697134e-03, 9.54868121e-05]))
scaler = load(open('scaler_v1.pkl', 'rb'))
# Out:
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator StandardScaler from version 0.22.2.post1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(

# %%
scaler.mean_, scaler.scale_
# Out:
# (array([-2.20681035e-11,  7.85894841e-03,  1.92149912e-08,  1.38805767e-07,
#          3.96657293e+03, -1.45941754e-04,  5.42086609e-04, -1.21754470e-05]),
#  array([1.46399667e-10, 7.07289355e-01, 1.89893314e-07, 4.55081599e-07,
#         1.44475515e+03, 4.87804804e-03, 4.64697134e-03, 9.54868121e-05]))

# %%
listyears = ["1872","1891","1892","1911","1912","1931","1932","1951","1952","1971","1972","1991","1992","2011"]

# %%
datapredicted_results = np.nan * np.zeros((7,)+Bathm.shape)

for i in range(7):
    
    print(listyears[2*i]+listyears[2*i+1])
    SSH20Mean = zos_xr.zos.isel(ensemble_member=0).sel(time=slice(listyears[2*i], listyears[2*i+1])).mean(axis=0).values
    TauUOMean = tauuo_xr.tauuo.isel(ensemble_member=0).sel(time=slice(listyears[2*i], listyears[2*i+1])).mean(axis=0).values
    TauVOMean = tauvo_xr.tauvo.isel(ensemble_member=0).sel(time=slice(listyears[2*i], listyears[2*i+1])).mean(axis=0).values

    ####
    print('Calculate grads')
    gradSSH_y, gradSSH_x = grad(SSH20Mean,latY,lonX)
    gradBathm_y, gradBathm_x = grad(Bathm,latY,lonX)
    gradUx_y, gradUx_x = grad(TauUOMean,latY,lonX)
    gradUy_y, gradUy_x = grad(TauVOMean,latY,lonX)
    ####
    print('Calculate CurlTau')
    curlTau =(gradUy_x-gradUx_y)/1032
    
    ####
    print('Calculate missindx')
    missingdataindex = np.isnan(curlTau*SSH20Mean*
                                   gradSSH_x*gradSSH_y*
                                   Bathm*gradBathm_x*
                                   gradBathm_y*f)
    ####
    print('Creating TotalDataset')
    TotalDataset = np.stack((curlTau[~missingdataindex],
                         SSH20Mean[~missingdataindex],
                         gradSSH_x[~missingdataindex],
                         gradSSH_y[~missingdataindex],
                         Bathm.values[~missingdataindex],
                         gradBathm_x[~missingdataindex],
                         gradBathm_y[~missingdataindex],
                         f[~missingdataindex]),1)
    ####
    print('NN pred')
    
    datapredicted_results_vanilla_ensemble = np.nan * np.zeros((50,TotalDataset.shape[0],6))

    for j in range(50):
        I1 = Input(shape=(8,)) 
        h1 = Dense(24, activation='tanh')(I1)
        h1 = Dense(24, activation='tanh')(h1)
        h1 = Dense(16, activation='tanh')(h1)
        h1 = Dense(16, activation='tanh')(h1)
        Output = Dense(6, activation='softmax')(h1)
        vanillamodel = Model(I1, Output)
        vanillamodel.load_weights(wgtsdir+'/vanillamodel_'+str(j)+'.h5') ###path in github repo
        datapredicted = vanillamodel.predict(scaler.transform(TotalDataset))#a1r
        datapredicted_results_vanilla_ensemble[j,...] = datapredicted
        
    tmpMean = np.mean(datapredicted_results_vanilla_ensemble,0)
    tmpSoftmax = special.softmax(tmpMean,1)
    datapredicted_results[i,:,:][~missingdataindex] = np.argmax(tmpSoftmax, 1)

    
np.save('/home/jovyan/DNN4Cli/THOR/ApplicationOnCMIPModels/IPSL-abrupt4pctCO2-198701-201112-EnsembleMLP.npy',datapredicted_results)
# Out:
# 18721891
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# Calculate grads
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# Calculate CurlTau
# Calculate missindx
# Creating TotalDataset
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# NN pred
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# 18921911
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# Calculate grads
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# Calculate CurlTau
# Calculate missindx
# Creating TotalDataset
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# NN pred
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# 19121931
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# Calculate grads
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# Calculate CurlTau
# Calculate missindx
# Creating TotalDataset
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# NN pred
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# 19321951
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# Calculate grads
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# Calculate CurlTau
# Calculate missindx
# Creating TotalDataset
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# NN pred
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# 19521971
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# Calculate grads
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# Calculate CurlTau
# Calculate missindx
# Creating TotalDataset
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# NN pred
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# 19721991
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# Calculate grads
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# Calculate CurlTau
# Calculate missindx
# Creating TotalDataset
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# NN pred
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# 19922011
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# Calculate grads
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# Calculate CurlTau
# Calculate missindx
# Creating TotalDataset
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# NN pred
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))

# %%
datapredicted_results.shape
# Out:
# (7, 332, 362)

# %%
from matplotlib.colors import ListedColormap
mycmap = ListedColormap(['royalblue', 'cyan','yellow', 'orange', 'magenta', 'red'])

# %%
ecco_label = np.load('eccolabel.npy')

# %%
plt.figure(figsize=(20,10))

plt.subplot(1,2,1)
plt.imshow(datapredicted_results[-1,:,:][::-1,:], cmap=mycmap)
plt.colorbar(fraction=0.024, pad=0.04)
plt.title('IPSL regimes 1992-2011 predicted by the Ensemble NN (4%CO2)')

plt.subplot(1,2,2)
plt.imshow(ecco_label[::-1,:], cmap=mycmap)
plt.colorbar(fraction=0.024, pad=0.04)
plt.title('ECCO regimes 1992-2011 (4%CO2)')
# Out:
# Text(0.5, 1.0, 'ECCO regimes 1992-2011 (4%CO2)')

# %% [markdown]
# # Save the images for the 20 years chunks

# %%
for i in range(7):
    plt.figure(figsize=(20,10))
    #plt.subplot(1,2,1)
    plt.imshow(datapredicted_results[i,:,:][::-1,:], cmap=mycmap)
    plt.colorbar(fraction=0.024, pad=0.04)
    plt.title('4%CO2 '+str(listyears[2*i])+' '+str(listyears[2*i+1]), fontsize=50)
    plt.savefig('png_4pctCO2_IPSL/'+str(listyears[2*i])+str(listyears[2*i+1])+'.png')

# %% [markdown]
# ## create a gif

# %%
import os
import imageio

png_dir = 'png_4pctCO2_IPSL/'
images = []
for file_name in sorted(os.listdir(png_dir)):
    if file_name.endswith('.png'):
        file_path = os.path.join(png_dir, file_name)
        images.append(imageio.imread(file_path))
imageio.mimsave('png_4pctCO2_IPSL/IPSL-png_Historical.gif', images, fps=1)
