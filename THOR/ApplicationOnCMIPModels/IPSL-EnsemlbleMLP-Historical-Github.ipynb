# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import intake,yaml
import intake_esm
from scipy import special
import keras
from keras.models import Model
from keras.layers import Dense, Input

from netCDF4 import Dataset
import scipy as sp
import scipy.io as sp_io
from mpl_toolkits.basemap import Basemap, cm, shiftgrid
import seaborn as sns
from matplotlib.colors import ListedColormap
colours=sns.color_palette('colorblind', 10)
my_cmap = ListedColormap(colours)

# %%
from cmip6_preprocessing.preprocessing import combined_preprocessing
from cmip6_preprocessing.preprocessing import (correct_units,rename_cmip6)

# %%
def pp_the(ds):
    ds = ds.copy()   #the wrapper function makes a copy of the ds and works from this
    ds = rename_cmip6(ds)
    ds = fix_time(ds)
    #ds = fix_units(ds)
    ds = correct_units(ds)
    return ds

# %% [markdown]
# ## Retrieve for the data (here example of IPSL-Historical)
#
# for the other models and scenarios, please change the variable "expname_filter" and "model_filter"

# %%
col_url = "https://cmip6-nc.s3.us-east-2.amazonaws.com/esgf-world.json" 
col = intake.open_esm_datastore(col_url)

# %%
# %pwd
# Out:
# '/home/jovyan/DNN4Cli/THOR/ApplicationOnCMIPModels'

# %%
#define location of weights file and image output here
import sys,os
wgtsdir = "../../ensembleMLP"
imgdir = "png_historical_IPSL"
if(os.path.exists(wgtsdir)):
    print("weight dir exists")
else:
    sys.exit("weights directory is invalid")
if(os.path.exists(wgtsdir+'/vanillamodel_0.h5')):
    print("weight file exists")
else:
    sys.exit("weights directory is invalid:"+wgtsdir+'/vanillamodel_0.h5')   
    
if not os.path.exists(imgdir):
    os.makedirs(imgdir)
# Out:
# weight dir exists
# weight file exists

# %%
#Examples to just search for what we want from the catalog
expname_filter = ['historical']
table_id_filter = 'Omon'
model_filter = 'IPSL-CM6A-LR'
#variable_id_filter = "zos"
grid_label_filter = 'gn'
ens_filter = "r1i1p1f1"
#version_filter = "v20190726"

cat_Hist = col.search(experiment_id=expname_filter,
                 mip_table=table_id_filter,
                 model=model_filter,
                 variable=['zos'],
                 grid_label=grid_label_filter,
                 ensemble_member = ens_filter
                )

col_tauuo_Hist = col.search(experiment_id=expname_filter,
                       model=model_filter,
                       mip_table=table_id_filter,
                       grid_label=grid_label_filter,
                       variable=['tauuo'],
                       ensemble_member = ens_filter
                       )

col_tauvo_Hist = col.search(experiment_id=expname_filter,
                       model=model_filter,
                       mip_table=table_id_filter,
                       grid_label=grid_label_filter,
                       variable=['tauvo'],
                       ensemble_member = ens_filter
                       )

col_bathm_Hist = col.search(experiment_id=['1pctCO2'],
                       model=model_filter,
                       mip_table='Ofx',
                       grid_label=grid_label_filter,
                       variable='deptho'
                       )

# %%
cat_Hist.df
# Out:
#   project institute         model experiment_id frequency modeling_realm  \
# 0   CMIP6      IPSL  IPSL-CM6A-LR    historical       mon          ocean
#
#   mip_table ensemble_member grid_label variable temporal subset    version  \
# 0      Omon        r1i1p1f1         gn      zos   185001-201412  v20180803
#
#                                                 path
# 0  s3://esgf-world/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/h...

# %%
col_bathm_Hist.df
# Out:
#   project institute         model experiment_id frequency modeling_realm  \
# 0   CMIP6      IPSL  IPSL-CM6A-LR       1pctCO2       NaN            NaN
#
#   mip_table ensemble_member grid_label variable temporal subset    version  \
# 0       Ofx        r1i1p1f1         gn   deptho             NaN  v20180727
#
#                                                 path
# 0  s3://esgf-world/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/1...

# %%
col_tauuo_Hist.df
# Out:
#   project institute         model experiment_id frequency modeling_realm  \
# 0   CMIP6      IPSL  IPSL-CM6A-LR    historical       mon          ocean
#
#   mip_table ensemble_member grid_label variable temporal subset    version  \
# 0      Omon        r1i1p1f1         gn    tauuo   185001-201412  v20180803
#
#                                                 path
# 0  s3://esgf-world/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/h...

# %%
col_tauvo_Hist.df
# Out:
#   project institute         model experiment_id frequency modeling_realm  \
# 0   CMIP6      IPSL  IPSL-CM6A-LR    historical       mon          ocean
#
#   mip_table ensemble_member grid_label variable temporal subset    version  \
# 0      Omon        r1i1p1f1         gn    tauvo   185001-201412  v20180803
#
#                                                 path
# 0  s3://esgf-world/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/h...

# %% [markdown]
# ### Read data

# %%
dset_dict_zos_Hist = cat_Hist.to_dataset_dict(cdf_kwargs={'chunks': {'time': 20}}, storage_options={'anon':True})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'project.institute.model.experiment_id.mip_table'
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:00<00:00]
#     </div>

# %%
dset_dict_tauuo_Hist = col_tauuo_Hist.to_dataset_dict(cdf_kwargs={'chunks': {'time': 20}}, storage_options={'anon':True})
dset_dict_tauvo_Hist = col_tauvo_Hist.to_dataset_dict(cdf_kwargs={'chunks': {'time': 20}}, storage_options={'anon':True})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'project.institute.model.experiment_id.mip_table'
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:00<00:00]
#     </div>
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'project.institute.model.experiment_id.mip_table'
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:00<00:00]
#     </div>

# %%
dset_dict_bathm_Hist = col_bathm_Hist.to_dataset_dict(storage_options={'anon':True})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'project.institute.model.experiment_id.mip_table'
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:00<00:00]
#     </div>

# %%
zos_xr_Hist = dset_dict_zos_Hist["CMIP6.IPSL.IPSL-CM6A-LR.historical.Omon"]
tauuo_xr_Hist = dset_dict_tauuo_Hist["CMIP6.IPSL.IPSL-CM6A-LR.historical.Omon"]
tauvo_xr_Hist = dset_dict_tauvo_Hist["CMIP6.IPSL.IPSL-CM6A-LR.historical.Omon"]
bathm_xr_Hist = dset_dict_bathm_Hist["CMIP6.IPSL.IPSL-CM6A-LR.1pctCO2.Ofx"]

# %% [markdown]
# ### Some plotting

# %%
plt.figure(figsize=(15,15))

plt.subplot(2,2,1)
zos_xr_Hist.zos.sel(time=slice("1992", "2011")).mean(axis=1).plot()

plt.subplot(2,2,2)
bathm_xr_Hist.deptho[0,:,:,:].max(axis=0).plot()

plt.subplot(2,2,3)
tauuo_xr_Hist.tauuo.sel(time=slice("1992", "2011")).mean(axis=1).plot()

plt.subplot(2,2,4)
tauvo_xr_Hist.tauvo.sel(time=slice("1992", "2011")).mean(axis=1).plot()
# Out:
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)

# %% [markdown]
# ### Preparing the features for the EnsembleMLP

# %%
def grad(d,y,x):
    "Returns a three point derivative."
    g0, g1 = np.gradient(d)
    grady=g0/y
    gradx=g1/x
    return grady, gradx

# %%
Bathm = bathm_xr_Hist.deptho[0,:,:,:].max(axis=0)  ###This is specific to IPSL bathymetry
####
lonRoll = np.roll(Bathm.nav_lon.values, axis=1, shift=-1)
Londiff = lonRoll - Bathm.nav_lon.values
latDiff=1.111774765625000e+05
latY=np.gradient(Bathm.nav_lat.values, axis=0)*latDiff
lonX=np.abs(np.cos(Bathm.nav_lat.values*np.pi/180))*latDiff*Londiff
####
Omega=7.2921e-5
f=(2*Omega*np.sin(Bathm.nav_lat.values*np.pi/180))

# %%
from pickle import load
#######!!!!!! it might ask you to use scikit-learn 0.22.2.post1 !!!!!! check if you get the good .mean_ and .scale_
#(array([-2.20681035e-11,  7.85894841e-03,  1.92149912e-08,  1.38805767e-07,
#         3.96657293e+03, -1.45941754e-04,  5.42086609e-04, -1.21754470e-05]),
# array([1.46399667e-10, 7.07289355e-01, 1.89893314e-07, 4.55081599e-07,
#        1.44475515e+03, 4.87804804e-03, 4.64697134e-03, 9.54868121e-05]))
scaler = load(open('scaler_v1.pkl', 'rb'))
# Out:
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator StandardScaler from version 0.22.2.post1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(

# %%
scaler.mean_, scaler.scale_
# Out:
# (array([-2.20681035e-11,  7.85894841e-03,  1.92149912e-08,  1.38805767e-07,
#          3.96657293e+03, -1.45941754e-04,  5.42086609e-04, -1.21754470e-05]),
#  array([1.46399667e-10, 7.07289355e-01, 1.89893314e-07, 4.55081599e-07,
#         1.44475515e+03, 4.87804804e-03, 4.64697134e-03, 9.54868121e-05]))

# %%
listyears = ["1872","1891","1892","1911","1912","1931","1932","1951","1952","1971","1972","1991","1992","2011"]

# %%
datapredicted_results = np.nan * np.zeros((7,)+Bathm.shape)

for i in range(7):
    
    print(listyears[2*i]+listyears[2*i+1])
    SSH20Mean_Hist = zos_xr_Hist.zos.isel(ensemble_member=0).sel(time=slice(listyears[2*i], listyears[2*i+1])).mean(axis=0).values
    TauUOMean_Hist = tauuo_xr_Hist.tauuo.isel(ensemble_member=0).sel(time=slice(listyears[2*i], listyears[2*i+1])).mean(axis=0).values
    TauVOMean_Hist = tauvo_xr_Hist.tauvo.isel(ensemble_member=0).sel(time=slice(listyears[2*i], listyears[2*i+1])).mean(axis=0).values

    ####
    print('Calculate grads')
    gradSSH_y, gradSSH_x = grad(SSH20Mean_Hist,latY,lonX)
    gradBathm_y, gradBathm_x = grad(Bathm,latY,lonX)
    gradUx_y, gradUx_x = grad(TauUOMean_Hist,latY,lonX)
    gradUy_y, gradUy_x = grad(TauVOMean_Hist,latY,lonX)
    ####
    print('Calculate CurlTau')
    curlTau =(gradUy_x-gradUx_y)/1032
    
    ####
    print('Calculate missindx')
    missingdataindex = np.isnan(curlTau*SSH20Mean_Hist*
                                   gradSSH_x*gradSSH_y*
                                   Bathm*gradBathm_x*
                                   gradBathm_y*f)
    ####
    print('Creating TotalDataset')
    TotalDataset = np.stack((curlTau[~missingdataindex],
                         SSH20Mean_Hist[~missingdataindex],
                         gradSSH_x[~missingdataindex],
                         gradSSH_y[~missingdataindex],
                         Bathm.values[~missingdataindex],
                         gradBathm_x[~missingdataindex],
                         gradBathm_y[~missingdataindex],
                         f[~missingdataindex]),1)
    ####
    print('NN pred')
    
    datapredicted_results_vanilla_ensemble = np.nan * np.zeros((50,TotalDataset.shape[0],6))

    for j in range(50):
        I1 = Input(shape=(8,)) 
        h1 = Dense(24, activation='tanh')(I1)
        h1 = Dense(24, activation='tanh')(h1)
        h1 = Dense(16, activation='tanh')(h1)
        h1 = Dense(16, activation='tanh')(h1)
        Output = Dense(6, activation='softmax')(h1)
        vanillamodel = Model(I1, Output)
        vanillamodel.load_weights(wgtsdir+'/vanillamodel_'+str(j)+'.h5') ###path in github repo
        datapredicted = vanillamodel.predict(scaler.transform(TotalDataset))#a1r
        datapredicted_results_vanilla_ensemble[j,...] = datapredicted
        
    tmpMean = np.mean(datapredicted_results_vanilla_ensemble,0)
    tmpSoftmax = special.softmax(tmpMean,1)
    datapredicted_results[i,:,:][~missingdataindex] = np.argmax(tmpSoftmax, 1)


    ####
    
np.save('/home/jovyan/DNN4Cli/THOR/ApplicationOnCMIPModels/IPSL-Historical-198701-201112-EnsembleMLP.npy',datapredicted_results)
# Out:
# 18721891
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# Calculate grads
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# Calculate CurlTau
# Calculate missindx
# Creating TotalDataset
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# NN pred
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# 18921911
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# Calculate grads
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# Calculate CurlTau
# Calculate missindx
# Creating TotalDataset
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# NN pred
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# 19121931
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# Calculate grads
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# Calculate CurlTau
# Calculate missindx
# Creating TotalDataset
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# NN pred
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# 19321951
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# Calculate grads
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# Calculate CurlTau
# Calculate missindx
# Creating TotalDataset
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# NN pred
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# 19521971
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# Calculate grads
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# Calculate CurlTau
# Calculate missindx
# Creating TotalDataset
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# NN pred
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# 19721991
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# Calculate grads
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# Calculate CurlTau
# Calculate missindx
# Creating TotalDataset
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# NN pred
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# 19922011
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/array/numpy_compat.py:39: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# Calculate grads
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# Calculate CurlTau
# Calculate missindx
# Creating TotalDataset
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# NN pred
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/utils.py:34: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/dask/core.py:121: RuntimeWarning: All-NaN slice encountered
#   return func(*(_execute_task(a, cache) for a in args))
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-0db0b00aaee4> in <module>
#      58     ####
#      59
# ---> 60 np.save('/home/jovyan/DNN4Cli/THOR/ApplicationOnCMIPModels/IPSL-Historical-198701-201112-EnsembleMLP.npy',datapredicted_results_Hist)
#      61
#
# NameError: name 'datapredicted_results_Hist' is not defined

# %%
np.save('/home/jovyan/DNN4Cli/THOR/ApplicationOnCMIPModels/IPSL-Historical-198701-201112-EnsembleMLP.npy',datapredicted_results)

# %%
from matplotlib.colors import ListedColormap
mycmap = ListedColormap(['royalblue', 'cyan','yellow', 'orange', 'magenta', 'red'])

# %%
ecco_label = np.load('eccolabel.npy')

# %%
plt.figure(figsize=(20,10))

plt.subplot(1,2,1)
plt.imshow(datapredicted_results[-1,:,:][::-1,:], cmap=mycmap)
plt.colorbar(fraction=0.024, pad=0.04)
plt.title('IPSL regimes 1992-2011 predicted by the Ensemble NN (Historical)')

plt.subplot(1,2,2)
plt.imshow(ecco_label[::-1,:], cmap=mycmap)
plt.colorbar(fraction=0.024, pad=0.04)
plt.title('ECCO regimes 1992-2011 (Historical)')
# Out:
# Text(0.5, 1.0, 'ECCO regimes 1992-2011 (Historical)')

# %% [markdown]
# # Save the images for the 20 years chunks

# %%
for i in range(7):
    plt.figure(figsize=(20,10))
    #plt.subplot(1,2,1)
    plt.imshow(datapredicted_results[i,:,:][::-1,:], cmap=mycmap)
    plt.colorbar(fraction=0.024, pad=0.04)
    plt.title('historical '+str(listyears[2*i])+' '+str(listyears[2*i+1]), fontsize=50)
    plt.savefig('png_historical_IPSL/'+str(listyears[2*i])+str(listyears[2*i+1])+'.png')

# %% [markdown]
# ## create a gif

# %%
import os
import imageio

png_dir = 'png_historical_IPSL/'
images = []
for file_name in sorted(os.listdir(png_dir)):
    if file_name.endswith('.png'):
        file_path = os.path.join(png_dir, file_name)
        images.append(imageio.imread(file_path))
imageio.mimsave('png_historical_IPSL/IPSL-png_historical.gif', images, fps=1)
