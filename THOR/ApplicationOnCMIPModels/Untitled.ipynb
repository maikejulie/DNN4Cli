# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
imgIPSLHis1 = mpimg.imread("/home/jovyan/DNN4Cli/THOR/ApplicationOnCMIPModels/IPSL Model/png_historical_IPSL/18721891.png")

# %%
imgplot = plt.imshow(imgIPSLHis1)

# %%
plt.figure(figsize=(15,15))

plt.imshow(imgIPSLHis1)
plt.subplot(2,2,1)
# Out:
# <AxesSubplot:>
