# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # GFDL-ESM4

# %% [markdown]
# Loading SST(tos) anomalies for various experiments

# %%
# %pwd
# Out:
# '/home/jovyan/DNN4Cli/NINOArea_Calc'

# %%
esm_tos_his = np.load("nino3SST_calc/ESM4/index_nino3_hist.npy")

# %%
esm_tos_1pct = np.load("nino3SST_calc/ESM4/index_nino3_1pct.npy")

# %%
esm_tos_4x = np.load("nino3SST_calc/ESM4/index_nino3_4x.npy")

# %% [markdown]
# Loading Precipitation(PR) anomalies for various experiments

# %%
esm_pr_his= np.load("PrecipitationCalc/ESM4/anoma_nino3_hist.npy")

# %%
esm_pr_1pct = np.load("PrecipitationCalc/ESM4/anoma_nino3_1pct.npy")

# %%
esm_pr_4x = np.load("PrecipitationCalc/ESM4/anoma_nino3_4x.npy")

# %%
esm_rsst_his = np.load("nino3SST_calc/ESM4/RSST_nino3_hist.npy")

# %%
esm_rsst_1pct = np.load("nino3SST_calc/ESM4/RSST_nino3_1pct.npy")

# %%
esm_rsst_4x = np.load("nino3SST_calc/ESM4/RSST_nino3_4x.npy")

# %%
esm_pr_his.shape
# Out:
# (1, 384)

# %%
plt.figure(figsize=(8,5))
plt.plot(esm_tos_his[0], esm_pr_his[0], ".", color = "black")
plt.ylim(-3e-5,7e-5)
plt.xlim(-3,3)
plt.title("1980 -2011 Historical")
plt.ylabel("Precipitation Anomaly")
plt.xlabel("SST Anomaly")
plt.savefig(f"FINAL_PRESENT.png")

# %%
esm_pr_1pct.size
# Out:
# 384

# %%
plt.figure(figsize=(8,5))
plt.plot(esm_tos_1pct[0], esm_pr_1pct[0], ".", color = "blue")
plt.ylim(-3e-5,7e-5)
plt.xlim(-3,3)
plt.title("0120 -0150 " + r"1%CO$_2$")
plt.ylabel("Precipitation Anomaly")
plt.xlabel("SST Anomaly")
plt.savefig(f"FINAL_PRESENT.png")

# %%
plt.figure(figsize=(8,5))
plt.plot(esm_tos_4x[0], esm_pr_4x[0], ".", color = "red")
plt.ylim(-3e-5,7e-5)
plt.xlim(-3,3)
plt.title("0120 -0150 " + r"4xCO$_2$")
plt.ylabel("Precipitation Anomaly")
plt.xlabel("SST Anomaly")
plt.savefig(f"FINAL_PRESENT.png")

# %%
esm_tos_4x.shape
# Out:
# (1, 384)

# %%
plt.figure(figsize=(15,10))
his = plt.plot(esm_tos_his[0], esm_pr_his[0],".", color = "green", label = "historical")
_1pct = plt.plot(esm_tos_1pct[0], esm_pr_1pct[0], "*", color = "blue", label = r"1%CO$_2$")
_4x = plt.plot(esm_tos_4x[0], esm_pr_4x[0], "+", color = "red", label = r"4xCO$_2$")
plt.legend()
plt.ylim(-3e-5,7e-5)
plt.xlim(-3,3)

#plt.title("NINO3 REGION 0120 -0150 (ESM4 1%CO2)")
plt.ylabel("Precipitation Anomaly")
plt.xlabel("SST Anomaly")
plt.savefig(f"FINAL_PRESENT.png")

# %% [markdown]
# # CESM2

# %%
cesm_tos_his = np.load("nino3SST_calc/CESM2/CESM2_SST_nino3_hist.npy")

# %%
cesm_tos_1pct = np.load("nino3SST_calc/CESM2/CESM2_SST_nino3_1pct.npy")

# %%
cesm_tos_4x = np.load("nino3SST_calc/CESM2/CESM2_SST_nino3_4x.npy")

# %% [markdown]
# Loading Precipitation(PR) anomalies for various experiments

# %%
cesm_pr_his= np.load("PrecipitationCalc/CESM2/CESM2anoma_nino3_hist.npy")

# %%
cesm_pr_1pct = np.load("PrecipitationCalc/CESM2/CESM2anoma_nino3_1pct.npy")

# %%
cesm_pr_4x = np.load("PrecipitationCalc/CESM2/CESM2anoma_nino3_4x.npy")

# %%
cesm_pr_his.shape
# Out:
# (1, 384)

# %%
plt.figure(figsize=(8,5))
plt.plot(cesm_tos_his[0], cesm_pr_his[0], ".", color = "black")
plt.ylim(-3e-5,7e-5)
plt.xlim(-3,3)
plt.title("1980 -2011 Historical")
plt.ylabel("Precipitation Anomaly")
plt.xlabel("SST Anomaly")
plt.savefig(f"FINAL_PRESENT.png")

# %%
plt.figure(figsize=(8,5))
plt.plot(cesm_tos_1pct[0], cesm_pr_1pct[0], ".", color = "blue")
plt.ylim(-3e-5,7e-5)
plt.xlim(-3,3)
plt.title("0120 -0150 " + r"1%CO$_2$")
plt.ylabel("Precipitation Anomaly")
plt.xlabel("SST Anomaly")
plt.savefig(f"FINAL_PRESENT.png")

# %%
plt.figure(figsize=(8,5))
plt.plot(cesm_tos_4x[0], cesm_pr_4x[0], ".", color = "red")
plt.ylim(-3e-5,7e-5)
plt.xlim(-3,3)
plt.title("0120 -0150 " + r"4xCO$_2$")
plt.ylabel("Precipitation Anomaly")
plt.xlabel("SST Anomaly")
plt.savefig(f"FINAL_PRESENT.png")

# %%
cesm_tos_4x.shape
# Out:
# (1, 384)
