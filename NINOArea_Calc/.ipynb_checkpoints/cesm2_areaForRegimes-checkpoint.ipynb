# %%
import sys
from netCDF4 import Dataset
import numpy as np
import scipy as sp
import scipy.io as sp_io
import matplotlib.pyplot as plt
import intake_esm, intake
import seaborn as sns
from matplotlib.colors import ListedColormap
import xarray as xr
colours=sns.color_palette('colorblind', 10)
my_cmap = ListedColormap(colours)

# %%
#col_url = "https://cmip6-nc.s3.us-east-2.amazonaws.com/esgf-world.json" 
col_url = "https://raw.githubusercontent.com/aradhakrishnanGFDL/gfdl-aws-analysis/master/esm-collection-spec-examples/esgf-world.json"
col = intake.open_esm_datastore(col_url)
esmcol_data = col.esmcol_data 

def latest_version(cat):
    """
    input
    cat: esmdatastore
    output
    esmdatastore with latest DRS versions
    """
    latest_cat = cat.df.sort_values(by=['version','path']).drop_duplicates(['temporal_subset','source_id','table_id',
                                               'institution_id','variable_id','member_id',
                                               'grid_label','experiment_id'],keep='last')
    return latest_cat

# %%
query_Ofx = dict(experiment_id=['abrupt-4xCO2','1pctCO2','historical'],
                 table_id=['Ofx'],
               member_id=["r1i1p1f1"],
                 source_id=['CESM2'],
                 grid_label=['gn'],
                 variable_id=["areacello"])

cat_Ofx = col.search(**query_Ofx)
cat_Ofx_lat = latest_version(cat_Ofx) 
cat_Ofx_lat = intake.open_esm_datastore(cat_Ofx_lat,esmcol_data=esmcol_data)
dset_dict_Ofx = cat_Ofx_lat.to_dataset_dict(storage_options=dict(anon=True),cdf_kwargs={'decode_times': True,'chunks': {}})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'project.institution_id.source_id.experiment_id.table_id'
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3/3 00:00<00:00]
#     </div>
# /home/jovyan/my-conda-envs/enso_ml/lib/python3.9/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'areacello' has multiple fill values {1e+20, 1e+20}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(

# %%
ds2 = dset_dict_Ofx["CMIP6.NCAR.CESM2.historical.Ofx"] #xarray dataset object to access Ofx areacello dataset used to calculate the weighted average

# %%
kCluster6 = "/home/jovyan/DNN4Cli/THOR/ApplicationOnCMIPModels/CESM2/CESM2-Historical-198701-201112-EnsembleMLP.npy"

# %%
areaGlobal = ds2.areacello

# %%
labels2=np.load(kCluster6)

# %%
labels2.shape
# Out:
# (7, 384, 320)

# %%
#plt.imshow(np.flip(labels2[1][:][:]==5))

# %% [markdown]
# Plot all regime data

# %%
# First we check that they look OK, and have the same orientation.
plt.imshow(np.flip(labels2[0][:][:]))
plt.figure()

# %%
def distance_on_unit_sphere(lat1, long1, lat2, long2):

    # Convert latitude and longitude to
    # spherical coordinates in radians.
    degrees_to_radians = np.pi / 180.0

    # phi = 90 - latitude
    phi1 = (90.0 - lat1) * degrees_to_radians
    phi2 = (90.0 - lat2) * degrees_to_radians

    # theta = longitude
    theta1 = long1 * degrees_to_radians
    theta2 = long2 * degrees_to_radians
    # Compute spherical distance from spherical coordinates.
    # For two locations in spherical coordinates
    # (1, theta, phi) and (1, theta, phi)
    # cosine( arc length ) =
    #    sin phi sin phi' cos(theta-theta') + cos phi cos phi'
    # distance = rho * arc length
    cos = np.sin(phi1) * np.sin(phi2) * np.cos(theta1 - theta2) + np.cos(phi1) * np.cos(
        phi2
    )
    arc = np.arccos(cos)
    # Remember to multiply arc by the radius of the earth
    # in your favorite set of units to get length.
    return arc

# %%
def find_closest_grid_point(lon, lat, gridlon, gridlat):
    """find integer indices of closest grid point in grid of coordinates
    gridlon, gridlat for a given geographical lon/lat.
    PARAMETERS:
    -----------
        lon (float): longitude of point to find
        lat (float): latitude of point to find
        gridlon (numpy.ndarray): grid longitudes
        gridlat (numpy.ndarray): grid latitudes
    RETURNS:
    --------
    iclose, jclose: integer
        grid indices for geographical point of interest
    """

    if isinstance(gridlon, xr.core.dataarray.DataArray):
        gridlon = gridlon.values
    if isinstance(gridlat, xr.core.dataarray.DataArray):
        gridlat = gridlat.values
    dist = distance_on_unit_sphere(lat, lon, gridlat, gridlon)
    jclose, iclose = np.unravel_index(dist.argmin(), gridlon.shape)
    return iclose, jclose

# %%
i,j= find_closest_grid_point(-150, -5, ds2.lon, ds2.lat)#for southwest
i,j
# Out:
# (222, 168)

# %%
k,l = find_closest_grid_point(-90, 5, ds2.lon, ds2.lat)#for northwest
k,l
# Out:
# (275, 205)

# %% [markdown]
# ### Original pseudo code
#
# def creaCalc(data, areaData):
#
#     Get data and areaData into numpy arrays
#
#     Calculate area for the data for all the regimes
#
#     (This will be an array where only the areas that are covered by the different dynamical regimes are non-nan)
#
#     return areaDataRegime0, areaDataRegime1, areaDataRegime2, areaDataRegime3, areaDataRegime4, areaDataRegime5

# %%
def extractionAreaCalc(data, area,chunks=None):
    """Code to extract area of different regimes. In principle this is applicable to any field, not just the area."""
    '''
    input:
    data is the labelled regime data 
    area is the total area
    output:
    mask matrix, indexed by regime labels 0 to 5
    '''
    regimeData=np.array(data)         #May have to add selection of specific data
    areaData=np.array(area)           #May have to add selection of specific data
   # print(areaData.shape)
    #Create dummy variable
    Msk=np.zeros((6,chunks, data.shape[1], data.shape[2]))
    for chunk in np.arange(0,chunks): #just one chunk for now
        for regime in np.arange(0,6):     # Loop over regimes
            regimeIndexes=np.where(regimeData[chunk]!=regime)   # Determine where regimes are *NOT* present
            areaSelected=np.copy(areaData[0])
            areaSelected[regimeIndexes]=-9999 # Set areas there the regime is not present to zero. Can be np.nan too, but I'm not sure what will caouse the least trouble!
            Msk[regime][chunk]=areaSelected      # Slot into results matrix
           # plt.figure()                  # Can be commented out
           # plt.title("Chunk-"+(str)(chunk)+"-- Area of regime "+(str)(regime))
            #plt.imshow(np.rot90(Msk[regime][chunk])) #*land,1))       # Can be commented out
            #print(areaSelected[(areaSelected>0)])
            #print("test",Msk[regime][chunk][Msk[regime][chunk] > 0])
    return Msk                        # Decided to return one matric instead of 6 fields

#todo concatenate chunks in regimeData

# %%
areaData=np.array(areaGlobal)

Mask=extractionAreaCalc(labels2, areaGlobal,chunks=7)

# %%
labels2.shape
# Out:
# (7, 384, 320)

# %%
Mask.shape
# Out:
# (6, 7, 384, 320)

# %%
labels2.shape
# Out:
# (7, 384, 320)

# %%
#new_labels2=np.zeros((1, labels2[0][:][:].shape[0], labels2[0][:][:].shape[1]))

#new_labels2[0] = labels2[0][:]

# %%
plt.imshow(labels2[0])

# %%
da_regimeData = xr.DataArray(
        data=labels2,
        dims=["chunk","y", "x"],
)

# %%
da_regimeData[0].plot()

# %%
ds2
# Out:
# <xarray.Dataset>
# Dimensions:    (member_id: 1, nlat: 384, nlon: 320, vertices: 4)
# Coordinates:
#     lat        (nlat, nlon) float64 dask.array<chunksize=(384, 320), meta=np.ndarray>
#     lon        (nlat, nlon) float64 dask.array<chunksize=(384, 320), meta=np.ndarray>
#   * nlat       (nlat) int32 1 2 3 4 5 6 7 8 ... 377 378 379 380 381 382 383 384
#   * nlon       (nlon) int32 1 2 3 4 5 6 7 8 ... 313 314 315 316 317 318 319 320
#   * member_id  (member_id) <U8 'r1i1p1f1'
# Dimensions without coordinates: vertices
# Data variables:
#     areacello  (member_id, nlat, nlon) float32 dask.array<chunksize=(1, 384, 320), meta=np.ndarray>
#     lat_bnds   (nlat, nlon, vertices) float32 dask.array<chunksize=(384, 320, 4), meta=np.ndarray>
#     lon_bnds   (nlat, nlon, vertices) float32 dask.array<chunksize=(384, 320, 4), meta=np.ndarray>
# Attributes: (12/46)
#     Conventions:             CF-1.7 CMIP-6.2
#     activity_id:             CMIP
#     case_id:                 15
#     cesm_casename:           b.e21.BHIST.f09_g17.CMIP6-historical.001
#     contact:                 cesm_cmip6@ucar.edu
#     creation_date:           2019-01-17T00:41:10Z
#     ...                      ...
#     branch_time_in_parent:   [219000.]
#     branch_time_in_child:    [674885.]
#     branch_method:           standard
#     further_info_url:        https://furtherinfo.es-doc.org/CMIP6.NCAR.CESM2....
#     intake_esm_varname:      ['areacello']
#     intake_esm_dataset_key:  CMIP6.NCAR.CESM2.historical.Ofx

# %%
ds = xr.Dataset(
     data_vars=dict(
        regimeData=(["chunk","nlat","nlon"], da_regimeData),
        areaGlobal=(ds2.areacello),
        mask=(["regimeIndex","chunk","nlat", "nlon"], Mask),
    ),
     coords=dict(
         x=(ds2.nlon),
         y=(ds2.nlat),
         chunk=np.arange(7)
     )
)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:     (chunk: 7, member_id: 1, nlat: 384, nlon: 320, regimeIndex: 6)
# Coordinates:
#     lat         (nlat, nlon) float64 dask.array<chunksize=(384, 320), meta=np.ndarray>
#     lon         (nlat, nlon) float64 dask.array<chunksize=(384, 320), meta=np.ndarray>
#   * nlat        (nlat) int32 1 2 3 4 5 6 7 8 ... 377 378 379 380 381 382 383 384
#   * nlon        (nlon) int32 1 2 3 4 5 6 7 8 ... 313 314 315 316 317 318 319 320
#   * member_id   (member_id) <U8 'r1i1p1f1'
#     x           (nlon) int32 1 2 3 4 5 6 7 8 ... 313 314 315 316 317 318 319 320
#     y           (nlat) int32 1 2 3 4 5 6 7 8 ... 377 378 379 380 381 382 383 384
#   * chunk       (chunk) int64 0 1 2 3 4 5 6
# Dimensions without coordinates: regimeIndex
# Data variables:
#     regimeData  (chunk, nlat, nlon) float64 nan nan nan nan ... nan nan nan nan
#     areaGlobal  (member_id, nlat, nlon) float32 dask.array<chunksize=(1, 384, 320), meta=np.ndarray>
#     mask        (regimeIndex, chunk, nlat, nlon) float64 -9.999e+03 ... -9.99...

# %%
Mask.shape
# Out:
# (6, 7, 384, 320)

# %%
ds.regimeData[0].where(ds.regimeData[0] == 1).plot(cmap=my_cmap)

# %%
ds.mask[1][0].where(ds.mask[1][0] != -9999).plot(cmap=my_cmap)#        mask=(["regimeIndex","chunk","y", "x"], Mask),

# %%
ds.regimeData[0].where(ds.regimeData[0] == 1).plot(cmap=my_cmap)

# %%
regime_nino3 = ds.regimeData.sel(nlat= slice(j,l), nlon = slice(i, k))

# %%
regime_nino3[0].plot(cmap=my_cmap, x = "nlon", y  = "nlat")

# %%
mask_nino3 = ds.mask.sel(nlat = slice(j,l), nlon = slice(i, k))

# %%
mask_nino3.shape
# Out:
# (6, 7, 38, 54)

# %%
area_sum = np.zeros((1, 6))

# %%
#ds.mask[1][0].where(ds.mask[1][0] != -1).sel(y = slice(-5,5), x = slice(-150, -90)).plot()
c = 0
for chunk in np.arange(6,7):
    for regime in np.arange(0,6): 
        #plt.figure()
        mask_nino3_regime = ds.mask[regime][chunk].where(ds.mask[regime][chunk] != -9999).sel(nlat = slice(j,l), nlon = slice(i, k))
        #mask_nino3_regime.plot()
        avgarea = mask_nino3_regime.sum(dim=('nlon', 'nlat'))
        area_sum[c][regime] = avgarea
        #plt.title("Regime:"+(str)(regime)+"Average area:"+(str)(avgarea))
    c+=1

# %%
print ("Mean and std of 1 chunks of 20 years")
mean_his=np.zeros(6)
std_his=np.zeros(6)
for regime in range(0,6):
    all_chuncks = np.zeros(7)
    for yrs in range(0,1):
        all_chuncks[yrs] = area_sum[yrs][regime]
    mean_his[regime], std_his[regime] = all_chuncks.mean(), all_chuncks.std()
    print("mean= ", "{:e}".format(all_chuncks.mean()), "std= ", "{:e}".format(all_chuncks.std()))
# Out:
# Mean and std of 1 chunks of 20 years
# mean=  1.021058e+12 std=  2.501072e+12
# mean=  0.000000e+00 std=  0.000000e+00
# mean=  6.352512e+10 std=  1.556041e+11
# mean=  0.000000e+00 std=  0.000000e+00
# mean=  0.000000e+00 std=  0.000000e+00
# mean=  0.000000e+00 std=  0.000000e+00

# %%
area_sum
# Out:
# array([[7.14740912e+12, 0.00000000e+00, 4.44675849e+11, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00]])

# %% [markdown]
# ## 1%CO2

# %%
kCluster6_1pct = "/home/jovyan/DNN4Cli/THOR/ApplicationOnCMIPModels/CESM2/CESM2-1prctCO2-198701-201112-EnsembleMLP.npy"

# %%
labels_1pct = np.load(kCluster6_1pct)

# %%
labels_1pct.shape
# Out:
# (7, 384, 320)

# %%
plt.imshow(labels_1pct[0])

# %%
Mask_1pct=extractionAreaCalc(labels_1pct, areaGlobal,chunks=7)

# %%
#new_labels_1pct=np.zeros((1, labels_1pct[0][:][:].shape[0], labels_1pct[0][:][:].shape[1]))

#new_labels_1pct[0] = labels_1pct[0][:]

# %%
da_regimeData_1pct = xr.DataArray(
        data=labels_1pct,
        dims=["chunk","y", "x"],
)

# %%
ds_1pct = xr.Dataset(
     data_vars=dict(
        regimeData=(["chunk","nlat","nlon"], da_regimeData_1pct),
        areaGlobal=(ds2.areacello),
        mask=(["regimeIndex","chunk","nlat", "nlon"], Mask_1pct),
    ),
     coords=dict(
         x=(ds2.nlon),
         y=(ds2.nlat),
         chunk=np.arange(7)
     )
)

# %%
ds_1pct.regimeData[0].where(ds_1pct.regimeData[0] == 1).plot(cmap = my_cmap)

# %%
regime_nino3_1pct = ds_1pct.regimeData.sel(nlat = slice(j,l), nlon = slice(i, k))

# %%
regime_nino3_1pct[5].plot(cmap=my_cmap)

# %%
area_sum_1pct = np.zeros((3,6))

# %%
c = 0
for chunk in np.arange(4,7):
    for regime in np.arange(0,6): 
        #plt.figure()
        mask_nino3_regime_1pct = ds_1pct.mask[regime][chunk].where(ds_1pct.mask[regime][chunk] != -9999).sel(nlat = slice(j,l), nlon = slice(i, k))
        #mask_nino3_regime.plot()
        avgarea = mask_nino3_regime_1pct.sum(dim=('nlon', 'nlat'))
        area_sum_1pct[c][regime] = avgarea
        #plt.title("Regime:"+(str)(regime)+"Average area:"+(str)(avgarea))
    c+=1

# %%
print ("Mean and std of 7 chunks of 20 years")
mean_1pct = np.zeros(6)
std_1pct = np.zeros(6)
for regime in range(0,6):
    all_chuncks = np.zeros(7)
    for yrs in range(0,3):
        all_chuncks[yrs] = area_sum_1pct[yrs][regime]
    mean_1pct[regime], std_1pct[regime] = all_chuncks.mean(), all_chuncks.std()
    print("mean= ", "{:e}".format(all_chuncks.mean()), "std= ", "{:e}".format(all_chuncks.std()))
# Out:
# Mean and std of 7 chunks of 20 years
# mean=  2.790864e+12 std=  3.222739e+12
# mean=  2.046827e+10 std=  2.793804e+10
# mean=  4.424182e+11 std=  5.111756e+11
# mean=  0.000000e+00 std=  0.000000e+00
# mean=  0.000000e+00 std=  0.000000e+00
# mean=  0.000000e+00 std=  0.000000e+00

# %% [markdown]
# ## Abrupt-4xCO2

# %%
kCluster6_4x = "/home/jovyan/DNN4Cli/THOR/ApplicationOnCMIPModels/CESM2/CESM2-abrupt4CO2-198701-201112-EnsembleMLP.npy"

# %%
labels_4x = np.load(kCluster6_4x)

# %%
labels_4x.shape
# Out:
# (7, 384, 320)

# %%
plt.imshow(labels_4x[0])

# %%
Mask_4x = extractionAreaCalc(labels_4x, areaGlobal,chunks=7)

# %%
#new_labels_4x=np.zeros((1, labels_4x[0][:][:].shape[0], labels_4x[0][:][:].shape[1]))

#new_labels_4x[0] = labels_4x[0][:]

# %%
labels_4x.shape
# Out:
# (7, 384, 320)

# %%
da_regimeData_4x = xr.DataArray(
        data=labels_4x,
        dims=["chunk","y", "x"],
)

# %%
ds_4x = xr.Dataset(
     data_vars=dict(
        regimeData=(["chunk","nlat","nlon"], da_regimeData_4x),
        areaGlobal=(ds2.areacello),
        mask=(["regimeIndex","chunk","nlat", "nlon"], Mask_4x),
    ),
     coords=dict(
         x=(ds2.nlon),
         y=(ds2.nlat),
         chunk=np.arange(7)
     )
)

# %%
ds_4x.regimeData[0].where(ds_4x.regimeData[0] == 1).plot(cmap=my_cmap)

# %%
ds_4x.mask[1][5].where(ds_4x.mask[1][5] != -9999).plot(cmap=my_cmap)#        mask=(["regimeIndex","chunk","y", "x"], Mask),

# %%
regime_nino3_4x = ds_4x.regimeData.sel(nlat = slice(j,l), nlon = slice(i, k))

# %%
regime_nino3_1pct[0].plot(cmap=my_cmap)

# %%
area_sum_4x =np.zeros((3,6))

# %%
c = 0
for chunk in np.arange(4,7):
    for regime in np.arange(0,6): 
        #plt.figure()
        mask_nino3_regime_4x = ds_4x.mask[regime][chunk].where(ds_4x.mask[regime][chunk] != -9999).sel(nlat = slice(j,l), nlon = slice(i, k))
        #mask_nino3_regime.plot()
        avgarea = mask_nino3_regime_4x.sum(dim=('nlon', 'nlat'))
        area_sum_4x[c][regime] = avgarea
        #plt.title("Regime:"+(str)(regime)+"Average area:"+(str)(avgarea))
    c+=1

# %%
print ("Mean and std of 3 chunks of 20 years")
mean_4x = np.zeros(6)
std_4x = np.zeros(6)
for regime in range(0,6):
    all_chuncks = np.zeros(7)
    for yrs in range(0,3):
        all_chuncks[yrs] = area_sum_4x[yrs][regime]
    mean_4x[regime], std_4x[regime] = all_chuncks.mean(), all_chuncks.std()
    print("mean= ", "{:e}".format(all_chuncks.mean()), "std= ", "{:e}".format(all_chuncks.std()))
# Out:
# Mean and std of 3 chunks of 20 years
# mean=  2.896889e+12 std=  3.345215e+12
# mean=  8.550416e+10 std=  1.090757e+11
# mean=  2.713575e+11 std=  3.235501e+11
# mean=  0.000000e+00 std=  0.000000e+00
# mean=  0.000000e+00 std=  0.000000e+00
# mean=  0.000000e+00 std=  0.000000e+00

# %%
import pandas as pd
df = pd.DataFrame({"Mean_his": mean_his,
                  "Std_his": std_his,
                  "Mean_1%": mean_1pct,
                  "Std_1%": std_1pct,
                  "Mean_4x": mean_4x,
                  "Std_4x": std_4x
                 })
df
# Out:
#        Mean_his       Std_his       Mean_1%        Std_1%       Mean_4x  \
# 0  6.915302e+12  1.337780e+11  6.452240e+12  1.616687e+11  6.431903e+12
# 1  1.269495e+10  3.109614e+10  2.046827e+10  2.793804e+10  1.169597e+11
# 2  6.640885e+11  1.426117e+11  1.119377e+12  1.692650e+11  1.043223e+12
# 3  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 4  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 5  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
#          Std_4x
# 0  4.070470e+11
# 1  8.978102e+10
# 2  4.813375e+11
# 3  0.000000e+00
# 4  0.000000e+00
# 5  0.000000e+00

# %%
area_sum_1pct
# Out:
# array([[6.57350398e+12, 2.19747351e+10, 9.96606258e+11, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00],
#        [6.48487068e+12, 4.39742088e+10, 1.06324008e+12, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00],
#        [6.47767506e+12, 7.73289731e+10, 1.03708094e+12, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00]])

# %%
area_sum_4x
# Out:
# array([[6.72605643e+12, 1.51354418e+11, 7.14674124e+11, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00],
#        [6.71877952e+12, 1.47532871e+11, 7.25772580e+11, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00],
#        [6.83338741e+12, 2.99641856e+11, 4.59055703e+11, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00]])

# %%
MD = area_sum_1pct[:,0]

S_NV =area_sum_1pct[:,1]

N_NV = area_sum_1pct[:,2]

areass = [MD, S_NV, N_NV]

# %%
MD4x = area_sum_4x[:,0]
S_NV4x =area_sum_4x[:,1]
N_NV4x = area_sum_4x[:,2]

areass4x = [MD4x, S_NV4x, N_NV4x]

# %%
areass
# Out:
# [array([6.57350398e+12, 6.48487068e+12, 6.47767506e+12]),
#  array([2.19747351e+10, 4.39742088e+10, 7.73289731e+10]),
#  array([9.96606258e+11, 1.06324008e+12, 1.03708094e+12])]

# %%
areass4x
# Out:
# [array([6.72605643e+12, 6.71877952e+12, 6.83338741e+12]),
#  array([1.51354418e+11, 1.47532871e+11, 2.99641856e+11]),
#  array([7.14674124e+11, 7.25772580e+11, 4.59055703e+11])]

# %%
labels = ['Area MD', 'Area SSV', 'Area NSV', 'Area NL'
         ]

# %%
area_sum = area_sum[0].tolist()

# %%
area_sum
# Out:
# [7147409123584.0, 0.0, 444675849472.0, 0.0, 0.0, 0.0]

# %%
#area_sum.pop(3)
# Out:
# 0.0

# %%
area_sum
# Out:
# [7147409123584.0, 0.0, 444675849472.0]

# %%
labels = ['Area MD', 'Area SSV', 'Area NSV']

# %%
plt.figure(figsize=(8,6))
bplot1 = plt.boxplot(areass,
                      vert=True,  # vertical box alignment
                  patch_artist=True,# fill with color
                     widths = 0.5,
                labels=labels) 
bplot2 = plt.boxplot(areass4x,
                      vert =True,  # vertical box alignment
                  patch_artist=True,# fill with color
                     widths = 0.5,
                labels=labels)
plothis = plt.plot(labels, area_sum, '*', "green")

plt.yscale('log')
#plt.ylim (9.0e+11, 6.0e+12)
#(['A simple line'])
colors = ['darkblue','green', 'pink', 'lightblue']
colors = ["blue", "blue", "blue", "blue"]
#for bplot in (bplot1, bplot2):
    #for patch, color in zip(bplot['boxes'], colors):
        #patch.set_facecolor(color)
for patch in bplot1["boxes"]:
    patch.set(facecolor = 'blue')
for patch in bplot2["boxes"]:
    patch.set(facecolor = 'red')

plt.legend([bplot1["boxes"][0], bplot2["boxes"][0]], ['1%CO'+'\N{SUBSCRIPT TWO}', '4xCO'+'\N{SUBSCRIPT TWO}'], loc='upper right')
plt.show()
#plt.ylim (9.0e+11, 7.0e+12)
